# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanue1909/APlicadas/blob/main/MunozEmmanuel_A00410447.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Me  llamo emmanuel nací en Cali, un 19 de septiembre de 2007 donde mi mama era muy joven y mi papa me abandono debido a que tenia mucho trabajo. Mas sin embargo mi mama siempre cuido bien de mí y luego conoció a mi actual padrastro que siempre me trajo lo que necesitaba y nos ha mantenido de una forma muy buena y le doy gracias a el por eso, entre a estudiar desde muy pequeño y con eso mi mama logro tener buenas relaciones en colegios pero al final estudie en el colegio bilingüe anglo americano donde tuve grandes enseñanzas y profesores que lograron forjar mis valores y virtudes, me desempeñe también en el futbol y basquetbol durante un tiempo mientras aprendía guitarra aunque al final deje todo eso por el Icfes y una lesión que arruino carrera.

# %% [markdown]
# ![WhatsApp Image 2025-02-11 at 09.23.26.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *1. Eventually
# >Artista: Tame impala
# >>Compositor: Kevin Parker
#
# 2. Like him
# >Artista: Tyler The creator
# >>Compositor: Tyler Okonma
# 3. Lobo-hombre en paris
# >Artista: La Union
# >>Compositar: Rafael Abitbol
# 4. Lamento boliviano
# >Artista: Los enanitos verdes
# >>Compositor: Raul Gomez
# 5. Esta cobardia
# >Artista: Frankie Ruiz
# >>Compositor: F.M Moncada*

# %% [markdown]
# |Asignatura | Razon |
# |----------|-----------|
# |MAtematica aplicada       |  expandir mis conocimientos y profundizar en la matematica   |
# |Algoritmos y programacion       | porque  me enseñan un nuevo programa con el cual puedo mejorar mi codigo  |
# |Ingenieria de software | porque aprendo y mejoro mi trabajo en grupo

# %% [markdown]
# 1. El teorema de Pitágoras: $c^2=a^2+b^2$
#
# 2. Logaritmos:  $log \space xy = log \space x + log \space  y $
#
# 3. Cálculo: $\frac{df}{dt}= \displaystyle \lim_{h\to 0}=\frac{f(t+h )-f(t)}{h}$
#
# 4. La ley de gravitación universal: $F = G\frac{_{_m1 _m2}}{r^2}$
#
# 5. Raíz cuadrada de -1: $\textit{i} ^2 = -1$
#
# 6. Euler's Formula for polyhedra: $V - E + F = 2$
#
# 7. Normal distribution: $\Phi (x)=\frac{1}{\sqrt{2\mathbb{\pi \rho }}}\textit{e}^\frac{(x-\mu)^2}{2\rho ^2}$
#
# 8. Wave Equation: $\frac{\partial ^2u}{\partial t^2} = c^2 \frac{\partial ^2u}{\partial x^2}$
#
# 9. Fourier Transform: $f(ω)=\int_{\infty}^{\infty}f(x)e^{-2πixω}dx$
#
# 10. Navier Stokes Equation: $ \rho (\frac{\partial \textbf{v}}{\partial \textbf{t}} + \textbf{v}\cdot \nabla \textbf{v} ) = -\nabla \textbf{p}+ \nabla\cdot \textbf{T} + \textbf{f}$
#
# 11. Maxwell's equation: $\nabla \cdot  \textbf{E} = 0; \nabla \chi \textbf{E} = - \frac{1}{c} \frac{\partial H}{\partial t}; \nabla \cdot  \textbf{H} = 0; \nabla \chi \textbf{H} = \frac{1}{c} \frac{\partial E}{\partial t}$
#
# 12. Second Law of thermodinamics: $dS\geq 0$
#
# 13. Relativity: $E=mc^2$
#
# 14. Schrodinger's: $\textit{i}\textit{h} \frac{ \partial}{ \partial \textit{t}} \Psi = \textit{H}\Psi  $
#
# 15. Information Theory: $H=-∑p(x) logp(x)$
#
# 16. Chaos Theory: $x_{t+1}= kx_t (1-x_t)$
#
# 17. Black Scholes Equation: $\frac{1}{2}\sigma^2 S^2 \frac{ \partial^2V}{ \partial S^2} + rS \frac{ \partial V}{ \partial S} + \frac{ \partial V}{ \partial t} - rV = 0$
